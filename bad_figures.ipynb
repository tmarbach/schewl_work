# %%
import pandas as pd
from window_maker import pull_window
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("~/CNNworkspace/raterdata/dec21_cleanPennf1.csv")
class_list = ['c', 'i', 'w', 's','l','t', 'a','d']
sdf, clist = pull_window(df,25, ['s'])
sdf = pd.concat(sdf).reset_index()
# Out:
# Windows pulled

# %%
#sdf[['behavior','acc_x','acc_y','acc_z']].describe()

plt.plot(sdf.index, sdf['acc_x'], color='r', label='Line x')
plt.plot(sdf.index, sdf['acc_y'], color='g', label='Line y')
plt.plot(sdf.index, sdf['acc_z'], color='b', label='Line z')
plt.title("Original Still")
plt.legend()
plt.show()
# Out:
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ldf, clist = pull_window(df,25, ['l'])
ldf = pd.concat(ldf).reset_index()
plt.plot(ldf.index, ldf['acc_x'], color='r', label='Line x')
plt.plot(ldf.index, ldf['acc_y'], color='g', label='Line y')
plt.plot(ldf.index, ldf['acc_z'], color='b', label='Line z')
plt.title("Original Slither")
plt.legend()
plt.show()
# Out:
# Windows pulled
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
lif, clist = pull_window(df,25, ['i'])
lif = pd.concat(lif).reset_index()
plt.plot(lif.index, lif['acc_x'], color='r', label='Line x')
plt.plot(lif.index, lif['acc_y'], color='g', label='Line y')
plt.plot(lif.index, lif['acc_z'], color='b', label='Line z')
plt.title("Original Ingest")
plt.legend()
plt.show()
# Out:
# Windows pulled

# %%
ddf, clist = pull_window(df,25, ['d'])
ddf = pd.concat(ddf).reset_index()
plt.plot(ddf.index, ddf['acc_x'], color='r', label='Line x')
plt.plot(ddf.index, ddf['acc_y'], color='g', label='Line y')
plt.plot(ddf.index, ddf['acc_z'], color='b', label='Line z')
plt.title("Original Drag Carcass")
plt.legend()
plt.show()
# Out:
# Windows pulled

# %%
daf, clist = pull_window(df,25, ['a'])
daf = pd.concat(daf).reset_index()
plt.plot(daf.index, daf['acc_x'], color='r', label='Line x')
plt.plot(daf.index, daf['acc_y'], color='g', label='Line y')
plt.plot(daf.index, daf['acc_z'], color='b', label='Line z')
plt.title("Original Carcass Investigate")
plt.legend()
plt.show()
# Out:
# Windows pulled

# %%
ldf, clist = pull_window(df,25, ['l'])
ldf = pd.concat(ldf)
ldf[['behavior','acc_x','acc_y','acc_z']].describe()
# Out:
# Windows pulled
#                acc_x          acc_y          acc_z
# count  661125.000000  661125.000000  661125.000000
# mean        0.023732      -0.074929       0.948900
# std         0.188649       0.186847       0.141134
# min        -2.001000      -2.001000      -1.985000
# 25%        -0.031000      -0.212000       0.969000
# 50%        -0.010000      -0.081000       0.985000
# 75%         0.016000       0.063000       0.985000
# max         1.985000       1.985000       1.985000

# %%
df[df['behavior'] == 's'].describe()
#still
# Out:
#                acc_x          acc_y          acc_z       temp_c  \
# count  175343.000000  175343.000000  175343.000000  1403.000000
# mean        0.005459      -0.113439       0.980593    26.982894
# std         0.097267       0.124240       0.032786     0.135100
# min        -0.688000      -0.975000       0.425000    26.000000
# 25%        -0.033000      -0.203000       0.980000    27.000000
# 50%        -0.016000      -0.109000       0.985000    27.000000
# 75%         0.047000      -0.016000       0.989000    27.000000
# max         0.844000       0.719000       1.094000    28.000000
#
#        battery_voltage  metadata   input_index
# count        60.000000       0.0  1.753430e+05
# mean          4.120833       NaN  7.078382e+05
# std           0.003814       NaN  2.103920e+05
# min           4.110000       NaN  2.814200e+04
# 25%           4.120000       NaN  6.386785e+05
# 50%           4.120000       NaN  7.086390e+05
# 75%           4.120000       NaN  7.959005e+05
# ...

# %%
df[df['behavior'] == 'l'].describe() #slither
# Out:
#                acc_x          acc_y          acc_z       temp_c  \
# count  661127.000000  661127.000000  661127.000000  5289.000000
# mean        0.023732      -0.074929       0.948900    26.998109
# std         0.188649       0.186847       0.141133     0.182426
# min        -2.001000      -2.001000      -1.985000    26.000000
# 25%        -0.031000      -0.212000       0.969000    27.000000
# 50%        -0.010000      -0.081000       0.985000    27.000000
# 75%         0.016000       0.063000       0.985000    27.000000
# max         1.985000       1.985000       1.985000    28.000000
#
#        battery_voltage  metadata    input_index
# count       218.000000       0.0  661127.000000
# mean          4.128303       NaN  381860.951503
# std           0.005022       NaN  218325.454639
# min           4.120000       NaN   31317.000000
# 25%           4.130000       NaN  201298.500000
# 50%           4.130000       NaN  366580.000000
# 75%           4.130000       NaN  536561.500000
# ...

# %%
df[df['behavior'] == 't'].describe()
# Out:
#            acc_x      acc_y      acc_z  temp_c  battery_voltage  metadata  \
# count  14.000000  14.000000  14.000000     0.0              0.0       0.0
# mean    0.075929  -0.032357   0.932214     NaN              NaN       NaN
# std     0.518321   0.814327   0.375591     NaN              NaN       NaN
# min    -1.422000  -2.001000   0.453000     NaN              NaN       NaN
# 25%    -0.055000  -0.367000   0.715000     NaN              NaN       NaN
# 50%     0.266000  -0.031500   0.937500     NaN              NaN       NaN
# 75%     0.332250   0.117250   1.028000     NaN              NaN       NaN
# max     0.797000   1.688000   1.985000     NaN              NaN       NaN
#
#         input_index
# count  1.400000e+01
# mean   1.671466e+06
# std    4.183300e+00
# min    1.671459e+06
# 25%    1.671462e+06
# 50%    1.671466e+06
# 75%    1.671469e+06
# max    1.671472e+06

# %%
df[df['behavior'] == 'c'].describe()
# Out:
#              acc_x        acc_y        acc_z  temp_c  battery_voltage  \
# count  7450.000000  7450.000000  7450.000000    60.0         3.000000
# mean     -0.014557    -0.120465     0.982779    27.0         4.106667
# std       0.036598     0.139386     0.011790     0.0         0.005774
# min      -0.094000    -0.356000     0.945000    27.0         4.100000
# 25%      -0.044000    -0.223750     0.969000    27.0         4.105000
# 50%      -0.016000    -0.172000     0.985000    27.0         4.110000
# 75%       0.000000     0.000000     0.985000    27.0         4.110000
# max       0.125000     0.234000     1.047000    27.0         4.110000
#
#        metadata   input_index
# count       0.0  7.450000e+03
# mean        NaN  1.678342e+06
# std         NaN  2.150774e+03
# min         NaN  1.674617e+06
# 25%         NaN  1.676479e+06
# 50%         NaN  1.678342e+06
# 75%         NaN  1.680204e+06
# max         NaN  1.682066e+06

# %%
df[df['behavior'] == 'i'].describe()
# Out:
#               acc_x         acc_y         acc_z  temp_c  battery_voltage  \
# count  12425.000000  12425.000000  12425.000000    99.0         5.000000
# mean       0.051347     -0.094448      0.982839    27.0         4.104000
# std        0.106876      0.120119      0.013960     0.0         0.005477
# min       -0.078000     -0.328000      0.891000    27.0         4.100000
# 25%       -0.031000     -0.203000      0.970000    27.0         4.100000
# 50%        0.016000     -0.117000      0.985000    27.0         4.100000
# 75%        0.141000     -0.016000      0.991000    27.0         4.110000
# max        0.313000      0.297000      1.016000    27.0         4.110000
#
#        metadata   input_index
# count       0.0  1.242500e+04
# mean        NaN  1.695854e+06
# std         NaN  3.586933e+03
# min         NaN  1.689642e+06
# 25%         NaN  1.692748e+06
# 50%         NaN  1.695854e+06
# 75%         NaN  1.698960e+06
# max         NaN  1.702066e+06

# %%
df.to_feather('test.feather')

# %%
pd.read_feather('test.feather').head()
# Out:
#   behavior  acc_x  acc_y  acc_z          tag_id        date      time  \
# 0        s -0.016  0.031  1.000  Pen11_AXY#1_S1  17/05/2021  16:26:21
# 1        s -0.016  0.047  0.985  Pen11_AXY#1_S1  17/05/2021  16:26:21
# 2        s -0.016  0.031  1.000  Pen11_AXY#1_S1  17/05/2021  16:26:21
# 3        s -0.016  0.031  0.985  Pen11_AXY#1_S1  17/05/2021  16:26:21
# 4        s -0.016  0.016  0.985  Pen11_AXY#1_S1  17/05/2021  16:26:21
#
#   camera_date camera_time  temp_c  battery_voltage  metadata  input_index
# 0     3/20/18    20:11:31     NaN              NaN       NaN        28142
# 1     3/20/18    20:11:31     NaN              NaN       NaN        28143
# 2     3/20/18    20:11:31     NaN              NaN       NaN        28144
# 3     3/20/18    20:11:31     NaN              NaN       NaN        28145
# 4     3/20/18    20:11:31     NaN              NaN       NaN        28146

# %%
#TODO:
csv_list = ['~/raw_accel_data/2021-10-05-oreganus_Pen11_051721_4.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen3_091321_02.csv',
            '~/raw_accel_data/2021-10-05_oreganus_JLTA_051721_09_10.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen4_09032021_04.csv',
            '~/raw_accel_data/2021-10-05_oreganus_JLTA_051721_18.csv',
#             '~/raw_accel_data/2021-10-21_oreganus_JLTA_092021_13.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen11_051721_17_18.csv',
            '~/raw_accel_data/2021-10-21_oreganus_JLTA_092021_35.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen11__083121_41.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen3_091321_01.csv']
ldf = pd.concat([pd.read_csv(csv, low_memory=False) for csv in csv_list]).reset_index()
ldf.to_feather('total.feather')
# Out:
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (3,4,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (0,1,2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %%
# from random import sample

# sample([[0], [1], [2]], 2)
pd.read_feather('total.feather').head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7c211dcb9188> in <module>
#       2
#       3 # sample([[0], [1], [2]], 2)
# ----> 4 pd.read_feather('total.feather').Behavior.unique().sum()
#
# NameError: name 'pd' is not defined

# %%
# !wc -l total.feather
# Out:
# 648851 total.feather

# %%
# !wc -l ~/CNNworkspace/total_clean_data.csv
# Out:
# 606883 /home/tmarbach/CNNworkspace/total_clean_data.csv

# %%
# !wc -l ~/CNNworkspace/raterdata/dec21_cleanPennf1.csv
# Out:
# 860662 /home/tmarbach/CNNworkspace/raterdata/dec21_cleanPennf1.csv

# %%
# !wc -l ~/raw_accel_data/2021-10-21_oreganus_JLTA_092021_13.csv
# Out:
# 500001 /home/tmarbach/raw_accel_data/2021-10-21_oreganus_JLTA_092021_13.csv

# %%
pf = pd.read_csv("~/CNNworkspace/total_clean_data.csv")
pf = pf.rename(columns={"Behavior":"behavior"})
# Out:
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5,6,7,8,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tf, clist = pull_window(pf,25, ['d'])
tf = pd.concat(tf).reset_index()
plt.rcParams["figure.figsize"] = (20,4)
plt.plot(tf.index, tf['accX'], color='r', label='Line x')
plt.plot(tf.index, tf['accY'], color='g', label='Line y')
plt.plot(tf.index, tf['accZ'], color='b', label='Line z')
plt.title("Drag Carcass")
plt.legend()
plt.show()
# Out:
# Windows pulled

# %%
from window_maker import transform_xy

# %%
af, clist = pull_window(pf,25, ['a'])
af = pd.concat(af).reset_index()
af[['behavior','accX','accY','accZ']].describe()
# Out:
# Windows pulled
#                accX          accY          accZ
# count  26675.000000  26675.000000  26675.000000
# mean       0.051318      0.116435      0.937247
# std        0.087922      0.207303      0.061145
# min       -0.140700     -0.394000      0.734600
# 25%        0.000000      0.000000      0.922000
# 50%        0.031300      0.109400      0.953400
# 75%        0.062500      0.234000      0.984700
# max        0.408300      0.640800      1.050000

# %%
zf, clist = pull_window(pf,5, ['t'])
zf = pd.concat(zf).reset_index()
plt.plot(zf.index, zf['accX'], color='r', label='Line x')
plt.plot(zf.index, zf['accY'], color='g', label='Line y')
plt.plot(zf.index, zf['accZ'], color='b', label='Line z')
plt.title("Strike")
plt.legend()
plt.show()
# Out:
# Windows pulled

# %%
plt.plot(af.index, af['accX'], color='r', label='Line x')
plt.plot(af.index, af['accY'], color='g', label='Line y')
plt.plot(af.index, af['accZ'], color='b', label='Line z')
plt.title("Carcass Investigate")
plt.legend()
plt.show()

# %%
winf, clist = pull_window(pf,25, ['c'])
cf = pd.concat(winf).reset_index()
cf[['behavior','accX','accY','accZ']].describe()
# Out:
# Windows pulled
#                accX          accY          accZ
# count  66575.000000  66575.000000  66575.000000
# mean       0.017169      0.021935      0.948119
# std        0.067941      0.231709      0.045100
# min       -0.343900     -0.625000      0.734600
# 25%       -0.031000     -0.172000      0.922200
# 50%        0.007500      0.031000      0.965000
# 75%        0.063000      0.187600      0.985000
# max        0.359500      0.609600      1.125000

# %%
bdict = {'s': 0, 'l': 1, 't': 2, 'c': 3, 'a': 4, 'd': 5, 'i': 6, 'w': 7}

Xtransdata, ytransdata = transform_xy(winf, bdict)
#     Xdata, ydata = [], []
#     for window in windows:
#         Xdata.append([window.accX.mean(), window.accY.mean()].to_numpy())
#         ydata.append(classdict[window['behavior'].iloc[0]])
        
#     return np.stack(Xdata), np.asarray(ydata)

print(Xtransdata[0:5])
# Out:
# [[ 0.0064  -0.16456]
#  [ 0.01116 -0.19076]
#  [ 0.01592 -0.1946 ]
#  [ 0.01144 -0.21076]
#  [ 0.02096 -0.20716]]

# %%
plt.plot(cf.index, cf['accX'], color='r', label='Line x')
plt.plot(cf.index, cf['accY'], color='g', label='Line y')
plt.plot(cf.index, cf['accZ'], color='b', label='Line z')
plt.title("Sics")
plt.legend()
plt.show()

# %%
iff, clist = pull_window(pf,25, ['i'])
iff = pd.concat(iff).reset_index()
iff[['behavior','accX','accY','accZ']].describe()
# Out:
# Windows pulled
#                 accX           accY           accZ
# count  154900.000000  154900.000000  154900.000000
# mean        0.018256       0.086325       0.915419
# std         0.106256       0.286169       0.085664
# min        -0.625800      -0.391000      -1.047000
# 25%        -0.016000      -0.187600       0.906500
# 50%         0.032000       0.140700       0.937800
# 75%         0.078200       0.313000       0.953400
# max         0.313000       0.906500       1.156600

# %%
plt.plot(iff.index, iff['accX'], color='r', label='Line x')
plt.plot(iff.index, iff['accY'], color='g', label='Line y')
plt.plot(iff.index, iff['accZ'], color='b', label='Line z')
plt.title("Ingest")
plt.legend()
plt.show()
# Out:
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
wf, clist = pull_window(pf,25, ['w'])
wf = pd.concat(wf).reset_index()
wf[['behavior','accX','accY','accZ']].describe()
# Out:
# Windows pulled
#                accX          accY          accZ
# count  45450.000000  45450.000000  45450.000000
# mean       0.048358      0.061712      0.925270
# std        0.163356      0.222957      0.061801
# min       -0.515800     -0.484500      0.547100
# 25%        0.000000     -0.156000      0.922000
# 50%        0.093800      0.125000      0.938000
# 75%        0.156000      0.172000      0.953000
# max        0.372600      0.750200      1.078000

# %%
plt.plot(wf.index, wf['accX'], color='r', label='Line x')
plt.plot(wf.index, wf['accY'], color='g', label='Line y')
plt.plot(wf.index, wf['accZ'], color='b', label='Line z')
plt.title("Swallow")
plt.legend()
plt.show()

# %%
stf, clist = pull_window(pf,25, ['s'])
stf = pd.concat(stf).reset_index()
stf[['behavior','accX','accY','accZ']].describe()
# Out:
# Windows pulled
#                 accX           accY           accZ
# count  213525.000000  213525.000000  213525.000000
# mean       -0.096402       0.080271       0.927180
# std         0.218447       0.121530       0.072806
# min        -0.781500      -0.297000       0.609600
# 25%        -0.203000      -0.015600       0.938000
# 50%         0.022500       0.094000       0.947000
# 75%         0.063000       0.125000       0.953000
# max         0.172000       0.406400       1.031600

# %%
plt.plot(stf.index, stf['accX'], color='r', label='Line x')
plt.plot(stf.index, stf['accY'], color='g', label='Line y')
plt.plot(stf.index, stf['accZ'], color='b', label='Line z')
plt.title("Still")
plt.legend()
plt.show()
# Out:
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
pf = pd.read_csv("~/CNNworkspace/raterdata/")

# %%
slf, clist = pull_window(pf,25, ['l'])
slf = pd.concat(slf).reset_index()
slf[['behavior','accX','accY','accZ']].describe()
# Out:
# Windows pulled
#                accX          accY          accZ
# count  77350.000000  77350.000000  77350.000000
# mean       0.040727      0.081830      0.935941
# std        0.070907      0.186671      0.036617
# min       -0.203000     -0.500200      0.578000
# 25%       -0.016000     -0.046900      0.920075
# 50%        0.046900      0.073800      0.938000
# 75%        0.093800      0.234000      0.958000
# max        0.328200      0.568000      1.125000

# %%
plt.plot(slf.index, slf['accX'], color='r', label='Line x')
plt.plot(slf.index, slf['accY'], color='g', label='Line y')
plt.plot(slf.index, slf['accZ'], color='b', label='Line z')
plt.title("Slither")
plt.legend()
plt.show()
# Out:
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# ['~/raw_accel_data/2021-10-05-oreganus_Pen11_051721_4.csv',
#             '~/raw_accel_data/2021-10-05_oreganus_Pen3_091321_02.csv',
#             '~/raw_accel_data/2021-10-05_oreganus_JLTA_051721_09_10.csv',
#             '~/raw_accel_data/2021-10-05_oreganus_Pen4_09032021_04.csv',
#             '~/raw_accel_data/2021-10-05_oreganus_JLTA_051721_18.csv',
#             '~/raw_accel_data/2021-10-21_oreganus_JLTA_092021_13.csv',
#             '~/raw_accel_data/2021-10-05_oreganus_Pen11_051721_17_18.csv',
#             '~/raw_accel_data/2021-10-21_oreganus_JLTA_092021_35.csv',
#             '~/raw_accel_data/2021-10-05_oreganus_Pen11__083121_41.csv',
#             '~/raw_accel_data/2021-10-05_oreganus_Pen3_091321_01.csv']
file = pd.read_csv("~/raw_accel_data/2021-10-05-oreganus_Pen11_051721_4.csv")
numb = file.shape
fluff = file.dropna(subset=['Behavior'])
bler = fluff.shape
print("kept amount = ",bler)
print(numb[0]-bler[0])
# Out:
# kept amount =  (297324, 11)
# 202676

# %%
file = pd.read_csv('~/raw_accel_data/2021-10-05_oreganus_Pen11_051721_17_18.csv')
numb = file.shape
fluff = file.dropna(subset=['Behavior'])
bler = fluff.shape
print(fluff.Behavior.unique().sum())
print("kept amount = ",bler)
print(numb[0]-bler[0])
# Out:
# /home/tmarbach/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# tcadiwl
# kept amount =  (66878, 11)
# 553121

# %%
file = pd.read_csv('~/raw_accel_data/2021-10-05_oreganus_Pen4_09032021_04.csv')
numb = file.shape
fluff = file.dropna(subset=['Behavior'])
bler = fluff.shape
print(fluff.Behavior.unique().sum())
print("kept amount = ",fluff.shape[0])
print(numb[0]-bler[0])
# Out:
# tcadiwls
# kept amount =  56484
# 443516

# %%
#dropna(subset=['Behavior']).shape[0]
csv_list = ['~/raw_accel_data/2021-10-05-oreganus_Pen11_051721_4.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen3_091321_02.csv',
            '~/raw_accel_data/2021-10-05_oreganus_JLTA_051721_09_10.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen4_09032021_04.csv',
            '~/raw_accel_data/2021-10-05_oreganus_JLTA_051721_18.csv',
            #'~/raw_accel_data/2021-10-21_oreganus_JLTA_092021_13.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen11_051721_17_18.csv',
            '~/raw_accel_data/2021-10-21_oreganus_JLTA_092021_35.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen11__083121_41.csv',
            '~/raw_accel_data/2021-10-05_oreganus_Pen3_091321_01.csv']
counts = [pd.read_csv(csv, low_memory=False).dropna(subset=['Behavior']).shape[0] for csv in csv_list]
fullcount = [pd.read_csv(csv, low_memory=False).shape[0] for csv in csv_list]
print(sum(counts))
print(sum(fullcount))
# Out:
# 880015
# 4784797

# %%
beexy = pd.read_csv('~/raw_accel_data/2021-10-21_oreganus_JLTA_092021_13.csv')
beexy = beexy.dropna(subset=['Unnamed: 4'])
beexy['Unnamed: 4'].unique().sum()
beexy.shape[0]
# Out:
# 46482
